# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahibVentura/M-todos-de-Optimizaci-n-/blob/main/BiseccionFuncionIrracional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

a = -5
b = 5
X = np.linspace(a, b, 100)
Y = 5-(X**4 + 2*X**3 - 3*X**2 +13)**0.5

plt.figure()
plt.plot(X, Y, 'k')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.grid()
plt.show()

# %% [markdown]
# MÉTODO DE BISECCIÓN
# ![IMG_20240531_100321.jpg](data:image/jpeg;base64,...)

# %%
import sympy

#Definimos una funcion que calcula la derivada de la funcion original
def calcularderivada():
  X = sympy.Symbol('X')
  Y = 5-(X**4 + 2*X**3 - 3*X**2 +13)**0.5
  d1Y = sympy.diff(Y)
  print(Y)
  print(d1Y)


calcularderivada()
# Out:
# 5 - (X**4 + 2*X**3 - 3*X**2 + 13)**0.5
# -(2.0*X**3 + 3.0*X**2 - 3.0*X)/(X**4 + 2*X**3 - 3*X**2 + 13)**0.5

# %%
def Y(X):
  return 5 - (X**4 + 2*X**3 - 3*X**2 + 13)**0.5

# %%
def dY(X):
  return -(2.0*X**3 + 3.0*X**2 - 3.0*X)/(X**4 + 2*X**3 - 3*X**2 + 13)**0.5

# %%
# Método de biseccion en python
import numpy as np
def biseccion():
    a = -5
    b = 0
    epsilon = 0.001

    cont = 0
    registro = []

    while(True):
        alpha = (a+b)/2

        # Primera derivada en a
        dY_a = dY(a)

        #Primera derivada en alpha
        dY_alpha = dY(alpha)

        if(dY_a*dY_alpha < 0):
            b = alpha
        else:
            a = alpha
        Ya = Y(a)

        # Condicion de finalizacion
        if(np.abs(a-b) < epsilon):
            print('-------------------------------------------------------------')
            print("It: {:02} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, a, Ya))
            break

        cont = cont + 1
        registro.append([cont, a, Ya])
        print("It: {:02} - Eje X: {:.10f} - Eje X: {:.10f}".format(cont, a, Ya))

    return registro


reg1 = biseccion()
# Out:
# It: 01 - Eje X: -2.5000000000 - Eje X: 3.5638593384
# It: 02 - Eje X: -2.5000000000 - Eje X: 3.5638593384
# It: 03 - Eje X: -2.5000000000 - Eje X: 3.5638593384
# It: 04 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 05 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 06 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 07 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 08 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 09 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 10 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 11 - Eje X: -2.1875000000 - Eje X: 4.2207741065
# It: 12 - Eje X: -2.1862792969 - Eje X: 4.2207888527
# -------------------------------------------------------------
# It: 12 - Eje X: -2.1862792969 - Eje Y: 4.2207888527

# %% [markdown]
# ***Evaluación del método.***
#
# Vamos a plotear el proceso de evolución que el algoritmo siguió para encontrar el máximo .

# %%
def evaluacion(reg):
    reg = np.array(reg)
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    fig.suptitle('Analisis de convergencia')

    axs[0].axhline(-2.186, color='k', linewidth=3, linestyle='--')
    axs[0].plot(reg[:, 0], reg[:, 1], linewidth=4)
    axs[0].set_xlabel('Iteraciones')
    axs[0].set_ylabel('Eje X')
    axs[0].grid()
    axs[0].set_xlim([0, 15])

    axs[1].axhline(4.220, color='k', linewidth=3, linestyle='--')
    axs[1].plot(reg[:, 0], reg[:, 2], linewidth=4)
    axs[1].set_xlabel('Iteraciones')
    axs[1].set_ylabel('Eje Y')
    axs[1].grid()
    axs[1].set_xlim([0, 15])

    plt.show()


evaluacion(reg1)
