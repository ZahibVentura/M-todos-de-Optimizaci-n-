# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahibVentura/M-todos-de-Optimizaci-n-/blob/main/FuncionExponencialDiscontinua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import math

a = -4
b = 4
X = np.linspace(a, b, 100)
Y = np.exp(-X) * (np.log(np.abs(X)) + (X/np.abs(X)))

plt.figure()
plt.plot(X, Y, 'k')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.grid()
plt.show()

# %% [markdown]
# ##Biseccion##

# %%
import sympy as sp

#Definimos una funcion que calcula la derivada de la funcion original
def calcularderivada():
  X = sp.Symbol('X')
  Y = sp.exp(-X) * (sp.log(np.abs(X)) + (X/np.abs(X)))
  d1Y = sp.diff(Y)
  d2Y = sp.diff(d1Y)
  print(Y)
  print(d1Y)
  print(d2Y)
  return None

# %%
calcularderivada()
# Out:
# (X/Abs(X) + log(Abs(X)))*exp(-X)
# -(X/Abs(X) + log(Abs(X)))*exp(-X) + (-(re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*sign(X)/Abs(X)**2 + 1/Abs(X) + (re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*sign(X)/(X*Abs(X)))*exp(-X)
# (X/Abs(X) + log(Abs(X)))*exp(-X) - 2*(-(re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*sign(X)/Abs(X)**2 + 1/Abs(X) + (re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*sign(X)/(X*Abs(X)))*exp(-X) + (-(re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*Derivative(sign(X), X)/Abs(X)**2 - (re(X)*Derivative(re(X), (X, 2)) + im(X)*Derivative(im(X), (X, 2)) + Derivative(re(X), X)**2 + Derivative(im(X), X)**2)*sign(X)/Abs(X)**2 + 2*(re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))**2*sign(X)**2/(X*Abs(X)**3) + (re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*Derivative(sign(X), X)/(X*Abs(X)) - (re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*sign(X)/(X*Abs(X)**2) + (re(X)*Derivative(re(X), (X, 2)) + im(X)*Derivative(im(X), (X, 2)) + Derivative(re(X), X)**2 + Derivative(im(X), X)**2)*sign(X)/(X*Abs(X)) - (re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))**2*sign(X)**2/(X**2*Abs(X)**2) - (re(X)*Derivative(re(X), X) + im(X)*Derivative(im(X), X))*sign(X)/(X**2*Abs(X)))*exp(-X)

# %%
# Segunda Derivada
def d2Y(X):
  return (np.exp(-X)* X**3 - 2*np.exp(-X)*X*np.abs(X) - np.exp(-X)*np.abs(X) + np.exp(-X)*X**2*np.log(np.abs(X))*np.abs(X))/(X**2*np.abs(X))

# %%
# Funcion Original
def Y(X):
  return np.exp(-X) * (np.log(np.abs(X)) + (X/np.abs(X)))

# %%
# Derivada de la Funcion
def dY(X):
  return -np.exp(-X) * (np.log(np.abs(X)) + (X/np.abs(X))) + np.exp(-X)/X

# %%
 # Método de biseccion en python
import numpy as np
def biseccion():
    a = 0.1
    b = 3
    epsilon = 0.001

    cont = 0
    registro = []

    while(True):
        alpha = (a+b)/2

        # Primera derivada en a
        dY_a = dY(a)

        #Primera derivada en alpha
        dY_alpha = dY(alpha)

        if(dY_a*dY_alpha < 0):
            b = alpha
        else:
            a = alpha
        Ya = Y(a)

        # Condicion de finalizacion
        if(np.abs(a-b) < epsilon):
            print('-------------------------------------------------------------')
            print("It: {:02} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, a, Ya))
            break

        cont = cont + 1
        registro.append([cont, a, Ya])
        print("It: {:02} - Eje X: {:.10f} - Eje X: {:.10f}".format(cont, a, Ya))

    return registro

# %%
reg1 = biseccion()
# Out:
# It: 01 - Eje X: 0.1000000000 - Eje X: -1.1786277323
# It: 02 - Eje X: 0.8250000000 - Eje X: 0.3539308975
# It: 03 - Eje X: 0.8250000000 - Eje X: 0.3539308975
# It: 04 - Eje X: 0.8250000000 - Eje X: 0.3539308975
# It: 05 - Eje X: 0.9156250000 - Eje X: 0.3649835456
# It: 06 - Eje X: 0.9609375000 - Eje X: 0.3672916737
# It: 07 - Eje X: 0.9835937500 - Eje X: 0.3677784997
# It: 08 - Eje X: 0.9949218750 - Eje X: 0.3678698981
# It: 09 - Eje X: 0.9949218750 - Eje X: 0.3678698981
# It: 10 - Eje X: 0.9977539063 - Eje X: 0.3678775804
# It: 11 - Eje X: 0.9991699219 - Eje X: 0.3678791874
# -------------------------------------------------------------
# It: 11 - Eje X: 0.9998779297 - Eje Y: 0.3678794357

# %%
def evaluacion(reg):
    reg = np.array(reg)
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    fig.suptitle('Analisis de convergencia')

    axs[0].axhline(1.000, color='k', linewidth=3, linestyle='--')
    axs[0].plot(reg[:, 0], reg[:, 1], linewidth=4)
    axs[0].set_xlabel('Iteraciones')
    axs[0].set_ylabel('Eje X')
    axs[0].grid()
    axs[0].set_xlim([0, 15])

    axs[1].axhline(0.367, color='k', linewidth=3, linestyle='--')
    axs[1].plot(reg[:, 0], reg[:, 2], linewidth=4)
    axs[1].set_xlabel('Iteraciones')
    axs[1].set_ylabel('Eje Y')
    axs[1].grid()
    axs[1].set_xlim([0, 15])

    plt.show()


evaluacion(reg1)

# %% [markdown]
# ##Secante##

# %%
def Secante():
    a= 0.1
    b= 3
    epsilon = 0.001

    cont = 0
    registro = []

    while True:
        # calcular f'(a)
        dY_a = dY(a)

        # calcular f'(b)
        dY_b= dY(b)

        # calcular alpha
        alpha = b - dY_b / ((dY_b - dY_a)/(b - a))

        dY_alpha = dY(alpha)

        if dY_alpha < 0:
            b = alpha
        else:
            a = alpha

        Y1_alpha = Y(alpha)

        cont = cont + 1

        registro.append([cont, alpha, Y1_alpha])
        print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, alpha, Y1_alpha))

        if np.abs(dY_alpha) <= epsilon:
            print("------------------------------------------------------------------------")
            print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, alpha, Y1_alpha))
            break

    return registro

# %%
reg2 = Secante()
# Out:
# It: 01 - Eje X: 2.9752905376 - Eje Y: 0.1066755819
# It: 02 - Eje X: 2.9503397047 - Eje Y: 0.1089300869
# It: 03 - Eje X: 2.9251473941 - Eje Y: 0.1112490150
# It: 04 - Eje X: 2.8997137935 - Eje Y: 0.1136341208
# It: 05 - Eje X: 2.8740394106 - Eje Y: 0.1160871603
# It: 06 - Eje X: 2.8481251005 - Eje Y: 0.1186098842
# It: 07 - Eje X: 2.8219720941 - Eje Y: 0.1212040298
# It: 08 - Eje X: 2.7955820279 - Eje Y: 0.1238713120
# It: 09 - Eje X: 2.7689569760 - Eje Y: 0.1266134130
# It: 10 - Eje X: 2.7420994822 - Eje Y: 0.1294319710
# It: 11 - Eje X: 2.7150125950 - Eje Y: 0.1323285678
# It: 12 - Eje X: 2.6876999029 - Eje Y: 0.1353047147
# It: 13 - Eje X: 2.6601655712 - Eje Y: 0.1383618375
# It: 14 - Eje X: 2.6324143798 - Eje Y: 0.1415012591
# It: 15 - Eje X: 2.6044517625 - Eje Y: 0.1447241820
# It: 138 - Eje X: 1.0028131109 - Eje Y: 0.3678765395
# It: 139 - Eje X: 1.0026313302 - Eje Y: 0.3678769018
# It: 140 - Eje X: 1.0024612740 - Eje Y: 0.3678772190
# It: 141 - Eje X: 1.0023021889 - Eje Y: 0.3678774966
# It: 142 - Eje X: 1.0021533694 - Eje Y: 0.3678777396
# It: 143 - Eje X: 1.0020141553 - Eje Y: 0.3678779523
# It: 144 - Eje X: 1.0018839284 - Eje Y: 0.3678781384
# It: 145 - Eje X: 1.0017621102 - Eje Y: 0.3678783012
# It: 146 - Eje X: 1.0016481591 - Eje Y: 0.3678784438
# It: 147 - Eje X: 1.0015415682 - Eje Y: 0.3678785685
# It: 148 - Eje X: 1.0014418633 - Eje Y: 0.3678786776
# It: 149 - Eje X: 1.0013486005 - Eje Y: 0.3678787732
# ------------------------------------------------------------------------
# It: 149 - Eje X: 1.0013486005 - Eje Y: 0.3678787732

# %%
def evaluacion(reg):
    reg = np.array(reg)
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    fig.suptitle('Analisis de convergencia')

    axs[0].axhline(1.000, color='k', linewidth=3, linestyle='--')
    axs[0].plot(reg[:, 0], reg[:, 1], linewidth=4)
    axs[0].set_xlabel('Iteraciones')
    axs[0].set_ylabel('Eje X')
    axs[0].grid()
    axs[0].set_xlim([0, 15])

    axs[1].axhline(0.367, color='k', linewidth=3, linestyle='--')
    axs[1].plot(reg[:, 0], reg[:, 2], linewidth=4)
    axs[1].set_xlabel('Iteraciones')
    axs[1].set_ylabel('Eje Y')
    axs[1].grid()
    axs[1].set_xlim([0, 15])

    plt.show()


evaluacion(reg2)

# %% [markdown]
# ##Metodo de NewtonRaphson##

# %%
def NewtonRaphson():
    a = -3
    b = 3
    x = 0.5
    epsilon = 0.001

    cont = 0
    registro = []

    while True:
        # Calculo de f'(x) y f''(x)
        dY_x = dY(x)
        d2Y_x = d2Y(x)

        xprev = x
        x = xprev - dY_x/d2Y_x

        Y_x = Y(x)

        cont = cont + 1
        registro.append([cont, x, Y_x])

        print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, x, Y_x))

        if(np.abs(x - xprev) <= epsilon):
            print("----------------------------------------------------------------")
            print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, x, Y_x))
            break

    return registro

# %%
reg3 = NewtonRaphson()
# Out:
# It: 01 - Eje X: 0.7200851148 - Eje Y: 0.3268818746
# It: 02 - Eje X: 0.8978344862 - Eje Y: 0.3635402335
# It: 03 - Eje X: 0.9838479636 - Eje Y: 0.3677816329
# It: 04 - Eje X: 0.9995528722 - Eje Y: 0.3678793676
# It: 05 - Eje X: 0.9999996503 - Eje Y: 0.3678794412
# ----------------------------------------------------------------
# It: 05 - Eje X: 0.9999996503 - Eje Y: 0.3678794412

# %%
def evaluacion(reg):
    reg = np.array(reg)
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    fig.suptitle('Analisis de convergencia')

    axs[0].axhline(1.000, color='k', linewidth=3, linestyle='--')
    axs[0].plot(reg[:, 0], reg[:, 1], linewidth=4)
    axs[0].set_xlabel('Iteraciones')
    axs[0].set_ylabel('Eje X')
    axs[0].grid()
    axs[0].set_xlim([0, 15])

    axs[1].axhline(0.367, color='k', linewidth=3, linestyle='--')
    axs[1].plot(reg[:, 0], reg[:, 2], linewidth=4)
    axs[1].set_xlabel('Iteraciones')
    axs[1].set_ylabel('Eje Y')
    axs[1].grid()
    axs[1].set_xlim([0, 15])

    plt.show()


evaluacion(reg3)

# %% [markdown]
# ##Seccion Dorada##

# %%
def GoldenSectionSearch():
    a = -3
    b = 3
    tau = 2 - 1.618033988
    epsilon = 0.00001

    cont = 0
    registro = []

    while(True):
        # Calcular alpha1 y alpha2
        alpha1 = a*(1 - tau) + b*tau
        alpha2 = a*tau + b*(1 - tau)

        # Calcular f(alpha1) y f(alpha2)
        Y_alpha1 = Y(alpha1)
        Y_alpha2 = Y(alpha2)

        if(Y_alpha1 < Y_alpha2):
            a = alpha1
        else:
            b = alpha2

        cont = cont + 1
        registro.append([cont, alpha1, Y_alpha1])
        print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, alpha1, Y_alpha1))

        if(np.abs(Y_alpha1 - Y_alpha2) < epsilon):
            print("-------------------------------------------------------")
            print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, alpha1, Y_alpha1))
            break

    return registro

# %%
reg4 = GoldenSectionSearch()
# Out:
# It: 01 - Eje X: -0.7082039280 - Eje Y: -2.7308561953
# It: 02 - Eje X: 0.7082039381 - Eje Y: 0.3225944333
# It: 03 - Eje X: 0.1671842741 - Eje Y: -0.6672396660
# It: 04 - Eje X: 0.7082039357 - Eje Y: 0.3225944324
# It: 05 - Eje X: 1.0425724747 - Eje Y: 0.3672446852
# It: 06 - Eje X: 0.9148550573 - Eje Y: 0.3649276881
# It: 07 - Eje X: 1.0425724742 - Eje Y: 0.3672446853
# It: 08 - Eje X: 0.9937887618 - Eje Y: 0.3678651452
# It: 09 - Eje X: 0.9636387695 - Eje Y: 0.3673717862
# It: 10 - Eje X: 0.9937887617 - Eje Y: 0.3678651452
# It: 11 - Eje X: 0.9822724894 - Eje Y: 0.3677614033
# It: 12 - Eje X: 0.9937887616 - Eje Y: 0.3678651452
# It: 13 - Eje X: 1.0009062093 - Eje Y: 0.3678791394
# -------------------------------------------------------
# It: 13 - Eje X: 1.0009062093 - Eje Y: 0.3678791394

# %%
def evaluacion(reg):
    reg = np.array(reg)
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    fig.suptitle('Analisis de convergencia')

    axs[0].axhline(1.000, color='k', linewidth=3, linestyle='--')
    axs[0].plot(reg[:, 0], reg[:, 1], linewidth=4)
    axs[0].set_xlabel('Iteraciones')
    axs[0].set_ylabel('Eje X')
    axs[0].grid()
    axs[0].set_xlim([0, 15])

    axs[1].axhline(0.367, color='k', linewidth=3, linestyle='--')
    axs[1].plot(reg[:, 0], reg[:, 2], linewidth=4)
    axs[1].set_xlabel('Iteraciones')
    axs[1].set_ylabel('Eje Y')
    axs[1].grid()
    axs[1].set_xlim([0, 15])

    plt.show()


evaluacion(reg4)

# %% [markdown]
# ##Fibonacci##

# %%
def Fibonacci(*params):
    a   = params[0]
    b   = params[1]
    k   = params[2]
    it  = params[3]
    reg = params[4]
    L   = params[5]
    n   = params[6]
    fs  = params[7]
    ep  = params[8]

    i_arriba = n - k + 1
    i_abajo = n + 1
    Lk = L*fs[i_arriba]/fs[i_abajo]

    xa = a + Lk
    xb = b - Lk

    Y_xa = Y(xa)
    Y_xb = Y(xb)

    if(Y_xa < Y_xb):
        a = xa
    else:
        b = xb

    if(np.abs(Y_xa-Y_xb) > ep):
        k = k + 1
        it = it + 1

        reg.append([it, xa, Y_xa])
        print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(it, xa, Y_xa))

        return Fibonacci(a, b, k, it, reg, L, n, fs, ep)
    else:
        print("-------------------------------------------------------")
        print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(it, xa, Y_xa))

        return reg

# %%
def RunFibonacci():
    n = 30

    fs = [1, 1]
    for i in range(n):
        aux = fs[-1] + fs[-2]
        fs.append(aux)

    a, b, k = -3, 3, 2
    L = b - a

    return Fibonacci(a, b, k, 0, [], b-a, n, fs, 0.0001)

# %%
reg5 = RunFibonacci()
# Out:
# It: 01 - Eje X: -0.7082039325 - Eje Y: -2.7308561947
# It: 02 - Eje X: 0.7082039325 - Eje Y: 0.3225944312
# It: 03 - Eje X: 0.1671842700 - Eje Y: -0.6672396894
# It: 04 - Eje X: 0.7082039325 - Eje Y: 0.3225944312
# It: 05 - Eje X: 1.0425724725 - Eje Y: 0.3672446853
# It: 06 - Eje X: 0.9148550550 - Eje Y: 0.3649276879
# It: 07 - Eje X: 1.0425724725 - Eje Y: 0.3672446853
# It: 08 - Eje X: 0.9937887600 - Eje Y: 0.3678651452
# It: 09 - Eje X: 0.9636387675 - Eje Y: 0.3673717861
# -------------------------------------------------------
# It: 09 - Eje X: 0.9937887600 - Eje Y: 0.3678651452

# %%
def evaluacion(reg):
    reg = np.array(reg)
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    fig.suptitle('Analisis de convergencia')

    axs[0].axhline(1.000, color='k', linewidth=3, linestyle='--')
    axs[0].plot(reg[:, 0], reg[:, 1], linewidth=4)
    axs[0].set_xlabel('Iteraciones')
    axs[0].set_ylabel('Eje X')
    axs[0].grid()
    axs[0].set_xlim([0, 15])

    axs[1].axhline(0.367, color='k', linewidth=3, linestyle='--')
    axs[1].plot(reg[:, 0], reg[:, 2], linewidth=4)
    axs[1].set_xlabel('Iteraciones')
    axs[1].set_ylabel('Eje Y')
    axs[1].grid()
    axs[1].set_xlim([0, 15])

    plt.show()


evaluacion(reg5)
