# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahibVentura/M-todos-de-Optimizaci-n-/blob/main/SecanteFuncionIrracional3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

a = -5
b = 5
X = np.linspace(a, b, 100)
Y = 5-(X**4 + 2*X**3 - 3*X**2 +13)**0.5
plt.figure()
plt.plot(X, Y, 'k')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.grid()
plt.show()

# %% [markdown]
# ![IMG_20240531_122400.jpg](data:image/jpeg;base64,...)

# %%
import sympy
def CalcularDerivada():
    X = sympy.Symbol('X')
    Y = 5-(X**4 + 2*X**3 - 3*X**2 +13)**0.5

    dY = sympy.diff(Y)

    print(Y)
    print(dY)

# %%
CalcularDerivada()
# Out:
# 5 - (X**4 + 2*X**3 - 3*X**2 + 13)**0.5
# -(2.0*X**3 + 3.0*X**2 - 3.0*X)/(X**4 + 2*X**3 - 3*X**2 + 13)**0.5

# %%
# FUNCION ORIGINAL
def Y(X):
  return 5 - (X**4 + 2*X**3 - 3*X**2 + 13)**0.5

# %%
# DERIVADA DE LA FUNCION
def dY(X):
  return -(2.0*X**3 + 3.0*X**2 - 3.0*X)/(X**4 + 2*X**3 - 3*X**2 + 13)**0.5

# %%
def Secante():
    a= -5
    b= 5
    epsilon = 0.001

    cont = 0
    registro = []

    while True:
        # calcular f'(a)
        dY_a = dY(a)

        # calcular f'(b)
        dY_b= dY(b)

        # calcular alpha
        alpha = b - dY_b / ((dY_b - dY_a)/(b - a))

        dY_alpha = dY(alpha)

        if dY_alpha > 0:
            b = alpha
        else:
            a = alpha

        Y1_alpha = Y(alpha)

        cont = cont + 1

        registro.append([cont, alpha, Y1_alpha])
        print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, alpha, Y1_alpha))

        if np.abs(dY_alpha) <= epsilon:
            print("------------------------------------------------------------------------")
            print("It: {:02d} - Eje X: {:.10f} - Eje Y: {:.10f}".format(cont, alpha, Y1_alpha))
            break

    return registro

# %%
reg1 = Secante()
# Out:
# It: 01 - Eje X: -0.4590400398 - Eje Y: 1.5044609968
# It: 02 - Eje X: -0.7329579360 - Eje Y: 1.7000907400
# It: 03 - Eje X: -1.2604673050 - Eje Y: 2.4014087487
# It: 04 - Eje X: -2.4599018782 - Eje Y: 3.6990930673
# It: 05 - Eje X: -1.6793695575 - Eje Y: 3.2620261765
# It: 06 - Eje X: -2.0037877383 - Eje Y: 4.0075391717
# It: 07 - Eje X: -2.1762685982 - Eje Y: 4.2200082017
# It: 08 - Eje X: -2.1893658209 - Eje Y: 4.2207050459
# It: 09 - Eje X: -2.1861127239 - Eje Y: 4.2207890013
# ------------------------------------------------------------------------
# It: 09 - Eje X: -2.1861127239 - Eje Y: 4.2207890013

# %% [markdown]
# ##Evaluación del método.##
#
# Vamos a plotear el proceso de evolución que el algoritmo siguió para encontrar el mínimo.

# %%
def evaluacion(reg):
    reg = np.array(reg)
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))

    fig.suptitle('Analisis de convergencia')

    axs[0].axhline(-2.186, color='k', linewidth=3, linestyle='--')
    axs[0].plot(reg[:, 0], reg[:, 1], linewidth=4)
    axs[0].set_xlabel('Iteraciones')
    axs[0].set_ylabel('Eje X')
    axs[0].grid()
    axs[0].set_xlim([0, 15])

    axs[1].axhline(4.220, color='k', linewidth=3, linestyle='--')
    axs[1].plot(reg[:, 0], reg[:, 2], linewidth=4)
    axs[1].set_xlabel('Iteraciones')
    axs[1].set_ylabel('Eje Y')
    axs[1].grid()
    axs[1].set_xlim([0, 15])

    plt.show()


evaluacion(reg1)
